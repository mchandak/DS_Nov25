# %%
#  create an object
x1 = 10
x1
# Out:
# 10

# %%
type(x1)
# Out:
# int

# %%
x2 = 12.5
x2
# Out:
# 12.5

# %%
type(x2)

# %%
x3 = "apple"
x3
# Out:
# 'apple'

# %%
type(x3)

# %%
x4= True
x4
# Out:
# True

# %%
type(x4)

# %%
a=10
b= a>10
b
# Out:
# False

# %%
"""
# Arithematic operators

+ : Addition
- : Deduction
* : Multiplication
/ : Division
// : integer division or floor division
% : Modulus - return remainder -> it works better when num > den
** : power
"""

# %%
x1 = 27
x2 = 10

# %%
x1
# Out:
# 27

# %%
x2
# Out:
# 10

# %%
print("Addition: " , x1 + x2)
print("subraction: " , x1 - x2)
print("multiplication: " , x1 * x2)
print("division: " , x1 / x2)
print("integer division: " , x1 // x2)
print("reminder: " , x1 % x2)
print("power value: " , x1 ** 2)
# Out:
# Addition:  37
# subraction:  17
# multiplication:  270
# division:  2.7
# integer division:  2
# reminder:  7
# power value:  729

# %%
# Comparison/Relational operators - Returns boolean values
"""
== : equal-to operator
!= : Not-Equal-to operator
> : Greater than
>= : Greater than or equal to
< : Less than
<= : Less than or equal to
"""

# %%
x2
# Out:
# 10

# %%
x1
# Out:
# 10

# %%
x1 = x2
x1
# Out:
# 10

# %%
x1 != x2
# Out:
# True

# %%
x1 > x2
# Out:
# True

# %%
x1 < x2
# Out:
# False

# %%
"""
# Logical Operators - used along with relational expressions

and : returns True if both operands are True
or  : returns True if any one of the operands are True
not : opposite of the logical operator
"""

# %%
OrdAmount = 4000
OrdDay = "Mon"

# %%
discount = OrdAmount> 5000 and OrdDay =="Mon"
discount
# Out:
# False

# %%
discount = OrdAmount> 5000 or OrdDay =="Mon"
discount
# Out:
# True

# %%
username = 'xyz'
pwd = 1233
otp = 4578

# %%
username == 'xyz' and (pwd == 1234 or otp==4578)
# Out:
# True

# %%
age = 21
age >= 18
# Out:
# True

# %%
not(age < 18)
# Out:
# True
