# %% [markdown]
# List - A list is a data structure in Python  is a mutable, ordered sequence of elements.
# Lists are written with square brackets []

# %% [markdown]
# ## List

# %%
j1 = []
j1

# %%
type(j1)

# %%
#       0   1   2  3    4        5    6

j1  =  [10, 25, 2, 14, 'apple', True, 23.5]
j1
# Out:
# [10, 25, 2, 14, 'apple', True, 23.5]

# %%
len(j1)

# %%
j1

# %%
j1[4]

# %%
j1[4] = 50

# %%
j1
# Out:
# [10, 25, 2, 14, 50, True, 23.5]

# %%
j1[7] # we will get erros as below

# %%
j1.append(18)  # last place will be added
j1
# Out:
# [10, 25, 2, 14, 50, True, 23.5, 18]

# %%
j1.insert(5, 29)
j1
# Out:
# [10, 25, 2, 14, 50, 29, True, 23.5, 18]

# %%
j1.pop()  # removes last value
j1
# Out:
# [10, 25, 2, 14, 50, 29, True, 23.5]

# %%
j1.pop(1) # removes the values as per index
j1
# Out:
# [10, 2, 14, 50, 29, True, 23.5]

# %%
j1.remove(14) # delete an element by its value, not by index, first occurrence only
j1
# Out:
# [10, 2, 50, True, 23.5]

# %%
lst1= [70, 20, 40, 60, 80, 50]

# %%
lst1[2]

# %%
lst1[-2]

# %%
# Slicing list  (SLicing with steps)
# L [ start : stop : step ]

# %%
lst1= [70, 20, 40, 60, 80, 50,70,90]

# %%
lst1[1:4]
# Out:
# [20, 40, 60]

# %%
lst1[1:]
# Out:
# [20, 40, 60, 80, 50, 70, 90]

# %%
lst1[:4]
# Out:
# [70, 20, 40, 60]

# %%
lst1[1:6:2]
# Out:
# [20, 60, 50]

# %%
#Sorting list
lst1.sort()
lst1
# Out:
# [20, 40, 50, 60, 70, 70, 80, 90]

# %%
lst1.sort(reverse = True)
lst1
# Out:
# [90, 80, 70, 70, 60, 50, 40, 20]

# %%
sum(lst1)
# Out:
# 480

# %%
len(lst1)
# Out:
# 8

# %%
avg = sum(lst1)/len(lst1)
avg
# Out:
# 60.0

# %%
a = [1, 2]
b = [3, 4]
a.extend(b)  # Extend the list
a
# Out:
# [1, 2, 3, 4]

# %%
a = [1, 2]
b = [3, 4]
c = a + b  # Concatenates
print(c)
# Out:
# [1, 2, 3, 4]

# %%
c.clear()
c
# Out:
# []

# %% [markdown]
# ## Tuple

# %%
# tuple - It is immutable 
t1 = ()
t1 = (12,14,36, 15.6, True, "cat")
t1
# Out:
# (12, 14, 36, 15.6, True, 'cat')

# %%
type(t1)
# Out:
# tuple

# %%
t1[0]
# Out:
# 12

# %%
len(t1)
# Out:
# 6

# %%
t1[0] = 25  # tuple wont accept for changes
t1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 t1[0] = 25  # tuple wont accept for changes
#       2 t1
#
# TypeError: 'tuple' object does not support item assignment

# %%
t2 = (12, 10, 10,15, 23, 10,28)
t2
# Out:
# (12, 10, 10, 15, 23, 10, 28)

# %%
t2.count(10)  # counting the number of times the values appears
# Out:
# 3

# %% [markdown]
# ## Dictionary

# %%
# using dictionary - Dictionary has a key & value pair. It is written with curly brackets
dict1= {'Lap1':40000,'Lap2':50000,'Lap3':60000,'Lap4':30000}
dict1
# Out:
# {'Lap1': 40000, 'Lap2': 50000, 'Lap3': 60000, 'Lap4': 30000}

# %%
dict1['Lap2'] # Retrive
# Out:
# 50000

# %%
dict1['Lap5']=55000   #adding
dict1
# Out:
# {'Lap1': 40000, 'Lap2': 50000, 'Lap3': 60000, 'Lap4': 30000, 'Lap5': 55000}

# %%
dict1['Lap1']=45000        #updating
dict1
# Out:
# {'Lap1': 45000, 'Lap2': 50000, 'Lap3': 60000, 'Lap4': 30000, 'Lap5': 55000}

# %%
del(dict1['Lap4'])   # Deleting
dict1
# Out:
# {'Lap1': 45000, 'Lap2': 50000, 'Lap3': 60000, 'Lap5': 55000}

# %%
dict1.keys()
# Out:
# dict_keys(['Lap1', 'Lap2', 'Lap3', 'Lap5'])

# %%
lstkey=list(dict1.keys())
lstkey
# Out:
# ['Lap1', 'Lap2', 'Lap3', 'Lap5']

# %%
lstval=list(dict1.values())
lstval

# %%
book1= "100"
book2= "200"

# %%
int(book1)+int(book2)
# Out:
# 300

# %% [markdown]
# ## Set

# %%
# using sets - Set elements are unique. Duplicate elements are not allowed.
# Set is unordered, so it doesn’t support indexing 

s1 =  {75,14,25,10,68,14,25,19,25}
s1

# %%
lst1 = [75,14,25,10,68,14,25,19,25]
s2 = set (lst1)
s2

# %%
## Union
s1 = {1,2,3}
s2 = {3,4,5}

# %%
s1 | s2

# %%
## Intersection
s1 = {1,2,3,4}
s2 = {3,4,5}

# %%
s1 & s2
